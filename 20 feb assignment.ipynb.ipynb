# %% [markdown]
# ANSWER 1

# %% [markdown]
# GET and POST are HTTP methods used in web communication.
#
# GET:
#
# The GET method is used to retrieve data from a server.
# When a client sends a GET request, the server responds by sending the requested data back to the client.
# GET requests can have parameters appended to the URL, typically in the form of key-value pairs, which are visible in the URL.
# GET requests are idempotent, meaning that multiple identical requests should have the same effect as a single request.
# POST:
#
# The POST method is used to send data to a server to create or update a resource.
# When a client sends a POST request, the data is included in the body of the request instead of being appended to the URL.
# POST requests are not visible in the URL and can carry a larger amount of data compared to GET requests.
# POST requests are not idempotent, meaning that multiple identical requests can have different effects each time.
# In summary, GET is used to retrieve data, while POST is used to send data to be processed or stored on the server.

# %% [markdown]
# ANSWER 2

# %% [markdown]
# In Flask, the request object is used to access incoming request data. It allows you to retrieve data sent by the client in the request headers, query parameters, or form data. The request object provides a simple interface to access and manipulate this data.
#
# Using the request object, you can access information such as the request method (GET, POST, etc.), request headers, request data, and more. It enables you to handle different types of requests and retrieve the necessary data to process the request.

# %% [markdown]
# ANSWER 3

# %% [markdown]
# The redirect() function in Flask is used to redirect the user to a different route or URL. It allows you to send an HTTP redirect response to the client's browser, which instructs the browser to make a new request to the specified URL.
#
# Redirects are useful in various scenarios, such as after a successful form submission or when you want to direct the user to a different page or route. By using redirect(), you can easily navigate the user to a different location within your Flask application or to an external URL.

# %% [markdown]
# ANSWER 4

# %% [markdown]
# In Flask, templates are files containing static or dynamic content that define the structure and layout of web pages. They typically contain HTML code mixed with placeholders, called template variables, which can be replaced with dynamic content during runtime.
#
# The render_template() function in Flask is used to render templates. It takes a template file as input, along with any required variables, and generates the final HTML response. This function uses a template engine, such as Jinja2 (the default template engine in Flask), to process the template and substitute the variables with actual values.
#
# Templates allow you to separate the presentation logic from the application logic in your Flask application. They provide a convenient way to generate dynamic web pages by combining static content with dynamically generated content.

# %% [markdown]
# ANSWER 5

# %% [markdown]
# ![20 scren.png](attachment:09acaabb-ab0b-47a9-9434-5ecf23f127af.png)

# %% [markdown]
# ![Screenshot (11) RECENT.png](attachment:860ec8be-984d-4937-8323-2bc393e3d674.png)
